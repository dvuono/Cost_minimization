# %%
import pandas as pd
from bokeh.charts import Scatter, show, output_file, ColumnDataSource
from bokeh.plotting import figure
from bokeh.io import output_notebook
from bokeh.models import HoverTool, BoxSelectTool
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8d233a51-4c12-4d61-9fb4-375ad49fdaa2">Loading BokehJS ...</span>
#     </div>

# %%
### Dictionary of the number of A+T in each Amino Acid's Codon. 
pctat_dict = {
    'Alanine': (2/12),
    'Arginine': (5/18),
    'Asparagine': (5/6),
    'Aspartic acid': (3/6),
    'Cysteine': (3/6),
    'Glutamic acid': (3/6),
    'Glutamine': (3/6),
    'Glycine': (2/12),
    'Histidine': (3/6),
    'Isoleucine': (8/9),
    'Leucine': (6/12),
    'Lycine': (5/6),
    'Methionine': (2/3),
    'Phenylalanine': (5/6),
    'Proline': (2/12),
    'Serine': (9/18),
    'Threonine': (6/12),
    'Tryptophane': (1/3),
    'Tyrosine': (5/6),
    'Valine': (6/12)}

aa = ['Alanine', 'Arginine', 'Asparagine', 'Aspartic acid', 'Cysteine', 'Glutamic acid', 'Glutamine',  'Glycine',
      'Histidine', 'Isoleucine', 'Leucine', 'Lycine', 'Methionine', 'Phenylalanine', 'Proline', 'Serine','Threonine',  
      'Tryptophane', 'Tyrosine', 'Valine']
mw = [89.094, 174.203, 132.119, 133.104, 121.154, 147.131, 146.146, 75.067, 155.156, 131.175, 131.175, 146.189, 149.208,
      165.192, 115.132, 105.093, 119.119, 204.228, 181.191, 117.148]
pct_at = [pctat_dict['Alanine'], pctat_dict['Arginine'], pctat_dict['Asparagine'], pctat_dict['Aspartic acid'], pctat_dict['Cysteine'],
       pctat_dict['Glutamic acid'], pctat_dict['Glutamine'], pctat_dict['Glycine'], pctat_dict['Histidine'], pctat_dict['Isoleucine'],
       pctat_dict['Leucine'], pctat_dict['Lycine'], pctat_dict['Methionine'], pctat_dict['Phenylalanine'], pctat_dict['Proline'],
       pctat_dict['Serine'], pctat_dict['Threonine'], pctat_dict['Tryptophane'], pctat_dict['Tyrosine'], pctat_dict['Valine']]
biochem = ['nonpolar', 'basic', 'polar', 'acidic', 'nonpolar', 'acidic', 'polar',  'nonpolar',
      'basic', 'nonpolar', 'nonpolar', 'basic', 'nonpolar', 'nonpolar', 'nonpolar', 'polar','polar',  
      'nonpolar', 'polar', 'nonpolar']
biochem_col = ['blue', 'green', 'orange', 'red', 'blue', 'red', 'orange',  'blue',
      'green', 'blue', 'blue', 'green', 'blue', 'blue', 'blue', 'orange','orange',  
      'blue', 'orange', 'blue']

### Convert Lists to Pandas Dataframe
aa_dict = {
    'Amino_acid': aa,
    'Molecular_weight': mw,
    'Biochem_property': biochem,
    'Percent_AT': pct_at}

AA = pd.DataFrame(aa_dict)

row_labels = ['Ala','Arg','Asn','Asp','Cys','Glu','Gln','Gly','His','Ile','Leu','Lys','Met','Phe','Pro','Ser','Thr','Trp','Tyr','Val']
AA.index = row_labels

print(AA)
# Out:
#         Amino_acid Biochem_property  Molecular_weight  Percent_AT
# Ala        Alanine         nonpolar            89.094    0.166667
# Arg       Arginine            basic           174.203    0.277778
# Asn     Asparagine            polar           132.119    0.833333
# Asp  Aspartic acid           acidic           133.104    0.500000
# Cys       Cysteine         nonpolar           121.154    0.500000
# Glu  Glutamic acid           acidic           147.131    0.500000
# Gln      Glutamine            polar           146.146    0.500000
# Gly        Glycine         nonpolar            75.067    0.166667
# His      Histidine            basic           155.156    0.500000
# Ile     Isoleucine         nonpolar           131.175    0.888889
# Leu        Leucine         nonpolar           131.175    0.500000
# Lys         Lycine            basic           146.189    0.833333
# Met     Methionine         nonpolar           149.208    0.666667
# Phe  Phenylalanine         nonpolar           165.192    0.833333
# Pro        Proline         nonpolar           115.132    0.166667
# Ser         Serine            polar           105.093    0.500000
# Thr      Threonine            polar           119.119    0.500000
# Trp    Tryptophane         nonpolar           204.228    0.333333
# Tyr       Tyrosine            polar           181.191    0.833333
# Val         Valine         nonpolar           117.148    0.500000

# %% [markdown]
# # High-level Bokeh plotting

# %%
p = Scatter(AA, x='Percent_AT', y='Molecular_weight', color="Biochem_property", legend="top_left",
            xlabel="Percent AT", ylabel="Molecular Weight")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3d4012fb-72fb-4f05-9df9-24960e4d4b83"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("3d4012fb-72fb-4f05-9df9-24960e4d4b83");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3d4012fb-72fb-4f05-9df9-24960e4d4b83");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3d4012fb-72fb-4f05-9df9-24960e4d4b83' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a21c885b-b836-4495-b956-c44e8297e240":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["y_values","x_values"],"data":{"Biochem_property":["nonpolar","nonpolar","nonpolar","nonpolar","nonpolar","nonpolar","nonpolar","nonpolar","nonpolar","nonpolar"],"chart_index":[{"Biochem_property":"nonpolar"},{"Biochem_property":"nonpolar"},{"Biochem_property":"nonpolar"},{"Biochem_property":"nonpolar"},{"Biochem_property":"nonpolar"},{"Biochem_property":"nonpolar"},{"Biochem_property":"nonpolar"},{"Biochem_property":"nonpolar"},{"Biochem_property":"nonpolar"},{"Biochem_property":"nonpolar"}],"x_values":{"__ndarray__":"VVVVVVVVxT8AAAAAAADgP1VVVVVVVcU/HMdxHMdx7D8AAAAAAADgP1VVVVVVVeU/q6qqqqqq6j9VVVVVVVXFP1VVVVVVVdU/AAAAAAAA4D8=","dtype":"float64","shape":[10]},"y_values":{"__ndarray__":"vHSTGARGVkBg5dAi20leQD81XrpJxFJAmpmZmZllYECamZmZmWVgQC2yne+npmJAoBov3SSmZECcxCCwcshcQJ7vp8ZLh2lAtvP91HhJXUA=","dtype":"float64","shape":[10]}}},"id":"7e164a5d-c3ff-4b47-b17f-4e0b4435d185","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["y_values","x_values"],"data":{"Biochem_property":["acidic","acidic"],"chart_index":[{"Biochem_property":"acidic"},{"Biochem_property":"acidic"}],"x_values":{"__ndarray__":"AAAAAAAA4D8AAAAAAADgPw==","dtype":"float64","shape":[2]},"y_values":{"__ndarray__":"F9nO91OjYEDVeOkmMWRiQA==","dtype":"float64","shape":[2]}}},"id":"5b90b9ed-86b6-4f55-92a7-206c9d127889","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"881c4415-4436-4250-9aaa-6eae9a5f79fb","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"04ad752e-2d6d-4ced-a426-130d8ed3d2c2","type":"LinearAxis"}],"renderers":[{"id":"7df77af8-87ff-4c3e-8613-c93a9e6c2c10","type":"BoxAnnotation"},{"id":"ea1f74eb-60a5-4d6b-9be1-06672d5f9afe","type":"GlyphRenderer"},{"id":"cc098ea9-3803-4003-914d-f7ce0e4c41d1","type":"GlyphRenderer"},{"id":"395f6d81-5c5c-4a8d-9eeb-b784453065e2","type":"GlyphRenderer"},{"id":"0884f4ce-04bb-421a-b688-60a5dbdeae44","type":"GlyphRenderer"},{"id":"d9a92dae-84a4-47c5-ad4c-566970c9891b","type":"Legend"},{"id":"881c4415-4436-4250-9aaa-6eae9a5f79fb","type":"LinearAxis"},{"id":"04ad752e-2d6d-4ced-a426-130d8ed3d2c2","type":"LinearAxis"},{"id":"7250983a-7c30-4c34-a3e8-a9de0317f081","type":"Grid"},{"id":"bd6c2f6f-1eea-4557-9456-b54ed032e1d7","type":"Grid"}],"title":{"id":"622f6278-110b-452c-9db9-bec0ce70213a","type":"Title"},"tool_events":{"id":"cc4d02c4-a9ff-4476-baf5-c9d36f8160e1","type":"ToolEvents"},"toolbar":{"id":"f767be60-d8b3-426b-aaa7-033d1fd5ee2f","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"0c66bf24-f197-490b-a67c-044b155d10e0","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"1e431c89-5add-4ddb-b0cd-8dffa2476728","type":"Range1d"}},"id":"894e6265-3a2f-4e69-a2b6-c98efe8da9fe","subtype":"Chart","type":"Plot"},{"attributes":{"overlay":{"id":"7df77af8-87ff-4c3e-8613-c93a9e6c2c10","type":"BoxAnnotation"},"plot":{"id":"894e6265-3a2f-4e69-a2b6-c98efe8da9fe","subtype":"Chart","type":"Plot"}},"id":"5695e16d-958d-482c-8b16-fc4b0c0f6483","type":"BoxZoomTool"},{"attributes":{"axis_label":"Percent AT","formatter":{"id":"2c714d33-9e62-4cae-99fc-e5a898524750","type":"BasicTickFormatter"},"plot":{"id":"894e6265-3a2f-4e69-a2b6-c98efe8da9fe","subtype":"Chart","type":"Plot"},"ticker":{"id":"b3cec7de-88cc-4e3f-96ee-ea57fae71149","type":"BasicTicker"}},"id":"881c4415-4436-4250-9aaa-6eae9a5f79fb","type":"LinearAxis"},{"attributes":{"plot":{"id":"894e6265-3a2f-4e69-a2b6-c98efe8da9fe","subtype":"Chart","type":"Plot"}},"id":"24816af7-670f-469d-b768-35f96acb7c91","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"5b90b9ed-86b6-4f55-92a7-206c9d127889","type":"ColumnDataSource"},"glyph":{"id":"3980e1a9-c838-4971-ba5f-3c5a3e436fed","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"0884f4ce-04bb-421a-b688-60a5dbdeae44","type":"GlyphRenderer"},{"attributes":{},"id":"b7cd68fd-30a4-44d3-9c49-47e00979c08c","type":"BasicTicker"},{"attributes":{},"id":"b3cec7de-88cc-4 ...

# %% [markdown]
# ### But it doesn't tell you which points correspond to which Amino Acid
# ### (At least it gets pretty messy if you try)

# %% [markdown]
# # Low-level Bokeh plotting
# ### combining figure.circle with hovertool

# %%
def scatter_with_hover(df, x, y,
                       fig=None, hov_cols=None, name=None,
                       fig_width=500, fig_height=500, **kwargs):

    if fig is None:
        fig = figure(width=fig_width, height=fig_height, tools=['box_zoom', 'reset', 'save'])

    source = ColumnDataSource(data=df)

    if name is None:
        name = 'main'

    fig.circle(df[x], df[y], source=source, name=name, **kwargs)

    hover = HoverTool(names=[name])

    if hov_cols is None:
        hover.tooltips = [(c, '@' + c) for c in df.columns]
    else:
        hover.tooltips = [(c, '@' + c) for c in hov_cols]

#     hover.tooltips.append(('index', '$index'))

    fig.add_tools(hover)

    return fig

# %%
fig = figure(x_axis_label="Percent AT", y_axis_label="Molecular Weight (g/mol)", title='Percent AT vs Amino Acid MW')

p = scatter_with_hover(df = AA, x = 'Percent_AT', y = 'Molecular_weight', fig = fig, 
                         hov_cols = ['Amino_acid','Molecular_weight','Percent_AT', 'Biochem_property'], color = biochem_col, size = 10)

output_file("scatter.html")

show(p)
# Out:
# /Users/dvuono/anaconda/lib/python3.5/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
# /Users/dvuono/anaconda/lib/python3.5/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
# /Users/dvuono/anaconda/lib/python3.5/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
# /Users/dvuono/anaconda/lib/python3.5/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ef57d895-0e2c-4ab9-b702-a3753812c111"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ef57d895-0e2c-4ab9-b702-a3753812c111");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ef57d895-0e2c-4ab9-b702-a3753812c111");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ef57d895-0e2c-4ab9-b702-a3753812c111' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2af1c2ab-2aef-40e4-bc09-58e746d348ef":{"roots":{"references":[{"attributes":{"plot":{"id":"d55a8a37-ca39-4496-8a2f-9e3502ab1e6e","subtype":"Figure","type":"Plot"}},"id":"4131015b-4c78-4f0e-af45-b75ef928823b","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"d55a8a37-ca39-4496-8a2f-9e3502ab1e6e","subtype":"Figure","type":"Plot"}},"id":"9af41494-c86c-4164-bbf0-719b6f28b4ee","type":"HelpTool"},{"attributes":{"plot":{"id":"d55a8a37-ca39-4496-8a2f-9e3502ab1e6e","subtype":"Figure","type":"Plot"}},"id":"f53e8597-f257-4a8e-b775-7cf667d3809e","type":"SaveTool"},{"attributes":{"data_source":{"id":"ecdd7815-e39e-43e9-8246-a1ea0b960e5f","type":"ColumnDataSource"},"glyph":{"id":"14fcc2a9-4eda-4259-8b56-2774aa177691","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"name":"main","nonselection_glyph":{"id":"6d0a8d22-5415-4f09-bcf8-d985cafee0cc","type":"Circle"},"selection_glyph":null},"id":"6dbb846c-0f23-4da5-aa2b-7136e07f3d44","type":"GlyphRenderer"},{"attributes":{"fill_color":{"field":"fill_color"},"line_color":{"field":"line_color"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"14fcc2a9-4eda-4259-8b56-2774aa177691","type":"Circle"},{"attributes":{"callback":null},"id":"b59c51b0-7e08-428b-a77c-8a286616c3ec","type":"DataRange1d"},{"attributes":{"callback":null},"id":"93cfa780-879a-431d-8bf6-2c62a1661072","type":"DataRange1d"},{"attributes":{"axis_label":"Molecular Weight (g/mol)","formatter":{"id":"731796f2-691d-444c-a014-731a41e48bed","type":"BasicTickFormatter"},"plot":{"id":"d55a8a37-ca39-4496-8a2f-9e3502ab1e6e","subtype":"Figure","type":"Plot"},"ticker":{"id":"d78e1a43-f918-4404-9b90-7196d88913d8","type":"BasicTicker"}},"id":"3788020a-32bb-4ca0-b33f-6c61c01900dd","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":